# %% [markdown]
# 1

# %%
import numpy as np
import pandas as pd
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
examen=pd.DataFrame(exam_data)
examen
# Out:
#         name  score  attempts qualify
# 0  Anastasia   12.5         1     yes
# 1       Dima    9.0         3      no
# 2  Katherine   16.5         2     yes
# 3      James    NaN         3      no
# 4      Emily    9.0         2      no
# 5    Michael   20.0         3     yes
# 6    Matthew   14.5         1     yes
# 7      Laura    NaN         1      no
# 8      Kevin    8.0         2      no
# 9      Jonas   19.0         1     yes

# %%
examen.head(3)
# Out:
#         name  score  attempts qualify
# 0  Anastasia   12.5         1     yes
# 1       Dima    9.0         3      no
# 2  Katherine   16.5         2     yes

# %% [markdown]
# 2

# %%
examen.dropna(inplace=True)
examen
# Out:
#         name  score  attempts qualify
# 0  Anastasia   12.5         1     yes
# 1       Dima    9.0         3      no
# 2  Katherine   16.5         2     yes
# 4      Emily    9.0         2      no
# 5    Michael   20.0         3     yes
# 6    Matthew   14.5         1     yes
# 8      Kevin    8.0         2      no
# 9      Jonas   19.0         1     yes

# %% [markdown]
# 3

# %%
examen[['name','score']]
# Out:
#         name  score
# 0  Anastasia   12.5
# 1       Dima    9.0
# 2  Katherine   16.5
# 4      Emily    9.0
# 5    Michael   20.0
# 6    Matthew   14.5
# 8      Kevin    8.0
# 9      Jonas   19.0

# %% [markdown]
# 4

# %%
examen= pd.DataFrame(exam_data, index=labels)
print("Original rows:")
print(examen)
# Out:
# Original rows:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
examen.dropna(inplace=True)
examen
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
dict1={
    "name" : ["Suresh"], 
    "score": [15.5],
    "attempts": [1],
    "qualify": ["yes"]
 
}
examen1=pd.DataFrame(dict1)
examen=pd.concat([examen,examen1])
examen
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes
# 0     Suresh   15.5         1     yes

# %%
#examen.index=['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j','k']
#examen

# %%
examen.loc['k']=['Suresh',15.5,1,'yes']
examen
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes
# 0     Suresh   15.5         1     yes
# k     Suresh   15.5         1     yes

# %% [markdown]
# 5

# %%
examen.drop('attempts',axis=1)
# Out:
#         name  score qualify
# a  Anastasia   12.5     yes
# b       Dima    9.0      no
# c  Katherine   16.5     yes
# e      Emily    9.0      no
# f    Michael   20.0     yes
# g    Matthew   14.5     yes
# i      Kevin    8.0      no
# j      Jonas   19.0     yes
# 0     Suresh   15.5     yes
# k     Suresh   15.5     yes

# %% [markdown]
# 6

# %%
examen['success']=np.where(examen['score']>10,1,0)
examen
# Out:
#         name  score  attempts qualify  success
# a  Anastasia   12.5         1     yes        1
# b       Dima    9.0         3      no        0
# c  Katherine   16.5         2     yes        1
# e      Emily    9.0         2      no        0
# f    Michael   20.0         3     yes        1
# g    Matthew   14.5         1     yes        1
# i      Kevin    8.0         2      no        0
# j      Jonas   19.0         1     yes        1
# 0     Suresh   15.5         1     yes        1
# k     Suresh   15.5         1     yes        1

# %% [markdown]
# 7

# %%
examen.to_csv('file_name.csv')
